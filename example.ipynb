# %%
# %%capture
! rm -r NLPSample
! git clone https://github.com/NoahDrisort/NLPSample.git
# !python -m pip install -r requirements.txt
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')

# %%
# !mkdir NLPSample/checkpoints

# %%
# %cd NLPSample
# Out:
# /content/NLPSample

# %%
from IPython.display import Image
Image('DOC/structure.png', width=800)

# %%
Image('DOC/senlen.png', width=400)

# %%
Image('DOC/res1.png',width=800)

# %%
Image('DOC/res2.png', width=800)

# %%
Image('DOC/res3.png', width=800)

# %% [markdown]
# # Sentiment

# %% [markdown]
# ### RNN

# %%
# %%capture
# !bash run.sh train sentiment rnn

# %%
# !bash run.sh evaluation sentiment rnn
# Out:
# Model loaded from <== checkpoints/sen_rnn.pt
# Accuracy: 0.6721546170365068

# %% [markdown]
# ### GRU

# %%
# %%capture
# !bash run.sh train sentiment gru

# %%
# !bash run.sh evaluation sentiment gru
# Out:
# Model loaded from <== checkpoints/sen_gru.pt
# Accuracy: 0.7666428060128847

# %% [markdown]
# ### LSTM

# %%
# %%capture
# !bash run.sh train sentiment lstm

# %%
# !bash run.sh evaluation sentiment lstm
# Out:
# Model loaded from <== checkpoints/sen_lstm.pt
# Accuracy: 0.7451682176091625

# %% [markdown]
# ### Attention

# %% [markdown]
# Attention Dot

# %%
# %%capture
# !bash run.sh train sentiment att_dot

# %%
# !bash run.sh evaluation sentiment att_dot
# Out:
# Model loaded from <== checkpoints/sen_att_dot.pt
# /content/NLPSample/Sentiment_analysis/Glove/model/attention.py:96: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   attention_distribution = self.softmax(attention_score)
# Accuracy: 0.7394416607015032

# %% [markdown]
# Attention Additive

# %%
# %%capture
# !bash run.sh train sentiment att_add

# %%
# !bash run.sh evaluation sentiment att_add
# Out:
# Model loaded from <== checkpoints/sen_att_add.pt
# /content/NLPSample/Sentiment_analysis/Glove/model/attention.py:333: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   attention_distribution = self.softmax(attention_score)                                       # [batch, seq-len]
# Accuracy: 0.7365783822476736

# %% [markdown]
# Attention Multilicative

# %%
# %%capture
# !bash run.sh train sentiment att_mul

# %%
# !bash run.sh evaluation sentiment att_mul
# Out:
# Model loaded from <== checkpoints/sen_att_mul.pt
# /content/NLPSample/Sentiment_analysis/Glove/model/attention.py:208: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   attention_distribution = self.softmax(attention_score)                                       # [batch, seq-len]
# Accuracy: 0.7415891195418755

# %% [markdown]
# BiLSTM Attention Additive

# %%
# %%capture
# !bash run.sh train sentiment att_bilstm_add

# %%
# !bash run.sh evaluation sentiment att_bilstm_add
# Out:
# Model loaded from <== checkpoints/sen_att_bilstm_add.pt
# /content/NLPSample/Sentiment_analysis/Glove/model/attention.py:504: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   attention_distribution = self.softmax(attention_score)                                       # [batch, seq-len]
# Accuracy: 0.7523264137437365

# %% [markdown]
# ### BERT

# %%
# %%capture
# !bash run.sh train sentiment bert

# %%
# !bash run.sh evaluation sentiment bert
# Out:
# Model loaded from <== checkpoints/sen_bert.pt
# /content/NLPSample/Sentiment_analysis/BERT/model.py:105: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   attention_distribution = self.softmax(attention_score)                                       # [batch, seq-len]
# Accuracy: 0.8697208303507517

# %% [markdown]
# # Seqence Labeling

# %% [markdown]
# ### BiLSTM with CRF

# %%
# %%capture
# !bash run.sh train sequence bilstm

# %%
# !bash run.sh evaluation sequence bilstm
# Out:
# Model loaded from <== checkpoints/Seq_BiLSTM.pt
# Precision = 100.0 , Recall = 90.9090909090909 , F1 = 95.23809523809523

# %% [markdown]
# ### BERT

# %%
# %%capture
# !bash run.sh train sequence bert

# %%
# !bash run.sh evaluation sequence bert
# Out:
# Model loaded from <== checkpoints/seq_bert.pt
# ['O', 'B-artist', 'I-artist', 'O', 'O', 'B-playlist', 'I-playlist', 'O']
# ['O', 'O', 'O', 'O', 'B-party_size_number', 'O', 'O', 'O', 'O', 'O', 'O', 'B-spatial_relation', 'O', 'B-poi', 'O', 'O', 'B-cuisine', 'O']
# ['O', 'B-artist', 'I-artist', 'O', 'B-playlist_owner', 'B-playlist', 'I-playlist', 'I-playlist', 'I-playlist', 'I-playlist', 'I-playlist', 'I-playlist', 'O']
# ['O', 'O', 'B-condition_description', 'O', 'B-state', 'O', 'B-timeRange', 'I-timeRange', 'I-timeRange']
# ['O', 'B-artist', 'I-artist', 'B-music_item', 'O', 'O', 'O', 'B-sort']
# ['O', 'O', 'O', 'O', 'O', 'O', 'B-movie_type', 'I-movie_type', 'O', 'O', 'B-spatial_relation', 'I-spatial_relation']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-sort', 'I-sort', 'B-restaurant_type', 'O', 'B-country']
# ['O', 'O', 'O', 'O', 'B-current_location', 'O', 'B-timeRange']
# ...

# %%
from google.colab import drive
#drive.mount('/content/gdrive')
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls checkpoints
# Out:
# sen_att_add.pt	       sen_att_mul.pt  sen_gru.pt   Seq_BiLSTM.pt
# sen_att_bilstm_add.pt  sen_bert.pt     sen_lstm.pt

# %%
# !cp -r checkpoints/sen_att_bilstm_add.pt "/content/drive/My Drive/checkpoints"
